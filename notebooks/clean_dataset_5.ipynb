# %%
import pandas as pd

# %%
data=pd.read_csv("../data/raw/E-commerece sales data 2024(dataset5).csv",index_col=False)

# %%
data.head()
# Out:
#    user id                        product id Interaction type  \
# 0      1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1      2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2      3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3      4.0  18018b6bc416dab347b1b7db79994afa             view
# 4      5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
#
#         Time stamp  Unnamed: 4
# 0  10/10/2023 8:00         NaN
# 1  11/10/2023 8:00         NaN
# 2  12/10/2023 8:00         NaN
# 3  13/10/2023 8:00         NaN
# 4  14/10/2023 8:00         NaN

# %%
data.dtypes
# Out:
# user id             float64
# product id           object
# Interaction type     object
# Time stamp           object
# Unnamed: 4          float64
# dtype: object

# %%
data.describe()
# Out:
#            user id  Unnamed: 4
# count  2999.000000         0.0
# mean   1500.000000         NaN
# std     865.881054         NaN
# min       1.000000         NaN
# 25%     750.500000         NaN
# 50%    1500.000000         NaN
# 75%    2249.500000         NaN
# max    2999.000000         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user id           2999 non-null   float64
#  1   product id        2999 non-null   object
#  2   Interaction type  2871 non-null   object
#  3   Time stamp        2999 non-null   object
#  4   Unnamed: 4        0 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 128.8+ KB

# %%
data.nunique()
# Out:
# user id             2999
# product id          2999
# Interaction type       3
# Time stamp           366
# Unnamed: 4             0
# dtype: int64

# %%
#drop useless column
data = data.drop(columns=['unnamed:_4'])

# %%
#check for missing values
data.isnull().sum()
# Out:
# user_id             0
# product_id          0
# interaction_type    0
# time_stamp          0
# dtype: int64

# %%
#handles missing values
data = data.fillna(method='ffill')
# Out:
# C:\Users\majum\AppData\Local\Temp\ipykernel_3316\410179031.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill')

# %%
#check and remove for duplicates
data.duplicated().sum()
data=data.drop_duplicates()

# %%
#clean column names
data.columns = (data.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
#fix data types
data['user_id'] = data['user_id'].astype(int)
data['time_stamp'] = pd.to_datetime(data['time_stamp'], dayfirst=True)

# %%
#feature engineering 
data['year'] = data['time_stamp'].dt.year
data['month'] = data['time_stamp'].dt.month
data['day'] = data['time_stamp'].dt.day

# %%
#standardize interaction type
data['interaction_type'] = data['interaction_type'].str.lower()

# %%
data.dtypes
# Out:
# user_id                      int64
# product_id                  object
# interaction_type            object
# time_stamp          datetime64[ns]
# year                         int32
# month                        int32
# day                          int32
# dtype: object

# %%
data.to_csv("../data/processed/dataset5_clean.csv",index=False)
